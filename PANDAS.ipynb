# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.8 MB 656.4 kB/s eta 0:00:17
#     --------------------------------------- 0.2/10.8 MB 1.0 MB/s eta 0:00:11
#     --------------------------------------- 0.2/10.8 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.6/10.8 MB 2.5 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/10.8 MB 3.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.1/10.8 MB 3.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.4/10.8 MB 3.8 MB/s eta 0:00:03
#    ------ --------------------------------- 1.7/10.8 MB 4.2 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/10.8 MB 4.4 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
import pandas as pd
iris= pd.read_csv("iris_dataset.csv")
iris
print(type(iris))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
iris= pd.read_csv("iris_dataset.csv")
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# ...

# %%
df=iris.copy()

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                object
# dtype: object

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.columns=['sl','sw','pl','pw','type']
df.head()
# Out:
#     sl   sw   pl   pw         type
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.sl #OR We can write it as df["sl"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sl, Length: 150, dtype: float64

# %%
df.isnull()
# Out:
#         sl     sw     pl     pw   type
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# ..     ...    ...    ...    ...    ...
# 145  False  False  False  False  False
# 146  False  False  False  False  False
# 147  False  False  False  False  False
# 148  False  False  False  False  False
# 149  False  False  False  False  False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sl      0
# sw      0
# pl      0
# pw      0
# type    0
# dtype: int64

# %%
df.iloc[2:4,1:3]
# Out:
#     sw   pl
# 2  3.2  1.3
# 3  3.1  1.5

# %%
df.iloc[3:5,0:3]
# Out:
#     sl   sw   pl
# 3  4.6  3.1  1.5
# 4  5.0  3.6  1.4

# %%
df.loc[2:4]
# Out:
#     sl   sw   pl   pw         type
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.loc[8]
# Out:
# sl              4.4
# sw              2.9
# pl              1.4
# pw              0.2
# type    Iris-setosa
# Name: 8, dtype: object

# %% [markdown]
# ### Manipulating data in dataframe

# %%
df.head(7)
# Out:
#     sl   sw   pl   pw         type
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa

# %%
a=df.drop(0)
a.head()
# Out:
#     sl   sw   pl   pw         type
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.drop(2,inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw         type
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa
# 7  5.0  3.4  1.5  0.2  Iris-setosa

# %%
df.index
# Out:
# RangeIndex(start=3, stop=150, step=1)

# %%
df.index[1]
# Out:
# 4

# %%
df.index[2]
# Out:
# 5

# %%
df.index[3]
# Out:
# 6

# %%
df.drop(df.index[0],inplace=True)
df.head()
# Out:
#      sl   sw   pl   pw         type
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa

# %%
df.sl>5
# Out:
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: sl, Length: 142, dtype: bool

# %%
df[df.sl>5]
# Out:
#       sl   sw   pl   pw            type
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [116 rows x 5 columns]

# %%
df[df.type=="Iris-virginica"].head(10)
# Out:
#       sl   sw   pl   pw            type
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica

# %%
df.reset_index()
# Out:
#      index   sl   sw   pl   pw            type
# 0        7  5.0  3.4  1.5  0.2     Iris-setosa
# 1        8  4.4  2.9  1.4  0.2     Iris-setosa
# 2        9  4.9  3.1  1.5  0.1     Iris-setosa
# 3       10  5.4  3.7  1.5  0.2     Iris-setosa
# 4       11  4.8  3.4  1.6  0.2     Iris-setosa
# ..     ...  ...  ...  ...  ...             ...
# 137    145  6.7  3.0  5.2  2.3  Iris-virginica
# 138    146  6.3  2.5  5.0  1.9  Iris-virginica
# 139    147  6.5  3.0  5.2  2.0  Iris-virginica
# 140    148  6.2  3.4  5.4  2.3  Iris-virginica
# 141    149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [142 rows x 6 columns]

# %%
df.reset_index(drop=True)
# Out:
#       sl   sw   pl   pw            type
# 0    5.0  3.4  1.5  0.2     Iris-setosa
# 1    4.4  2.9  1.4  0.2     Iris-setosa
# 2    4.9  3.1  1.5  0.1     Iris-setosa
# 3    5.4  3.7  1.5  0.2     Iris-setosa
# 4    4.8  3.4  1.6  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 137  6.7  3.0  5.2  2.3  Iris-virginica
# 138  6.3  2.5  5.0  1.9  Iris-virginica
# 139  6.5  3.0  5.2  2.0  Iris-virginica
# 140  6.2  3.4  5.4  2.3  Iris-virginica
# 141  5.9  3.0  5.1  1.8  Iris-virginica
#
# [142 rows x 5 columns]

# %%
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#     sl   sw   pl   pw         type
# 0  5.0  3.4  1.5  0.2  Iris-setosa
# 1  4.4  2.9  1.4  0.2  Iris-setosa
# 2  4.9  3.1  1.5  0.1  Iris-setosa
# 3  5.4  3.7  1.5  0.2  Iris-setosa
# 4  4.8  3.4  1.6  0.2  Iris-setosa

# %%
#Drop a row
df.drop(140,inplace=True)
df.tail()
# Out:
#       sl   sw   pl   pw            type
# 136  6.7  3.3  5.7  2.5  Iris-virginica
# 137  6.7  3.0  5.2  2.3  Iris-virginica
# 138  6.3  2.5  5.0  1.9  Iris-virginica
# 139  6.5  3.0  5.2  2.0  Iris-virginica
# 141  5.9  3.0  5.1  1.8  Iris-virginica

# %%
#drop a column
df.drop('pl',axis=1)
# Out:
#       sl   sw   pw            type
# 0    5.0  3.4  0.2     Iris-setosa
# 1    4.4  2.9  0.2     Iris-setosa
# 2    4.9  3.1  0.1     Iris-setosa
# 3    5.4  3.7  0.2     Iris-setosa
# 5    4.3  3.0  0.1     Iris-setosa
# ..   ...  ...  ...             ...
# 136  6.7  3.3  2.5  Iris-virginica
# 137  6.7  3.0  2.3  Iris-virginica
# 138  6.3  2.5  1.9  Iris-virginica
# 139  6.5  3.0  2.0  Iris-virginica
# 141  5.9  3.0  1.8  Iris-virginica
#
# [140 rows x 4 columns]

# %%
#add a row
df.loc[149]=[1.1,2.2,3.3,"rose"]
df.tail()
# Out:
#       sl   pl   pw            type
# 137  6.7  5.2  2.3  Iris-virginica
# 138  6.3  5.0  1.9  Iris-virginica
# 139  6.5  5.2  2.0  Iris-virginica
# 141  5.9  5.1  1.8  Iris-virginica
# 149  1.1  2.2  3.3            rose

# %%
#add a column
df["difference"]=df["sl"]-df["pl"]
df.tail()
# Out:
#       sl   pl   pw            type  difference
# 137  6.7  5.2  2.3  Iris-virginica         1.5
# 138  6.3  5.0  1.9  Iris-virginica         1.3
# 139  6.5  5.2  2.0  Iris-virginica         1.3
# 141  5.9  5.1  1.8  Iris-virginica         0.8
# 149  1.1  2.2  3.3            rose        -1.1

# %% [markdown]
# ###
